# %%
import pandas as pd

# %%
data=pd.read_csv("student_data.csv")
data
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
data.columns
# Out:
# Index(['Student_ID', 'Major_Category', 'Year_of_Study', 'Pre_Semester_GPA',
#        'Weekly_GenAI_Hours', 'Primary_Use_Case', 'Prompt_Engineering_Skill',
#        'Tool_Diversity', 'Paid_Subscription', 'Traditional_Study_Hours',
#        'Perceived_AI_Dependency', 'Institutional_Policy',
#        'Anxiety_Level_During_Exams', 'Post_Semester_GPA',
#        'Skill_Retention_Score', 'Burnout_Risk_Level'],
#       dtype='str')

# %%
data.shape
# Out:
# (50000, 16)

# %%
data.info
# Out:
# <bound method DataFrame.info of        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(data["Perceived_AI_Dependency"])
plt.show()

# %%
data.drop(columns=["Year_of_Study","Primary_Use_Case","Tool_Diversity","Institutional_Policy","Anxiety_Level_During_Exams","Paid_Subscription"],inplace=True)
data
# Out:
#        Student_ID Major_Category  Pre_Semester_GPA  Weekly_GenAI_Hours  \
# 0          100001     Humanities             2.418               23.31
# 1          100002        Medical             3.821                1.12
# 2          100003       Business             3.398               21.26
# 3          100004       Business             3.789                1.82
# 4          100005           STEM             3.635                9.29
# ...           ...            ...               ...                 ...
# 49995      149996       Business             2.899               12.16
# 49996      149997           STEM             2.870                2.51
# 49997      149998       Business             3.177               15.87
# 49998      149999       Business             3.398               19.91
# 49999      150000           Arts             3.242                3.30
#
#       Prompt_Engineering_Skill  Traditional_Study_Hours  \
# 0                     Beginner                     8.13
# ...

# %%
data["Major_Category"].value_counts().plot(kind="pie")
plt.show()

# %%
data["Pre_Semester_GPA"].value_counts().plot(kind="hist")
plt.show()

# %%
data["Burnout_Risk_Level"].value_counts().plot(kind="bar")
plt.show()

# %%
data["Prompt_Engineering_Skill"].value_counts().plot(kind="bar")
plt.show()

# %%
data["Perceived_AI_Dependency"].value_counts().plot(kind="pie")
plt.show()
