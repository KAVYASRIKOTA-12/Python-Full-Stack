# %%
#pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.9 MB 4.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.9 MB 5.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/9.9 MB 4.2 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/9.9 MB 3.7 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/9.9 MB 3.4 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/9.9 MB 3.0 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/9.9 MB 3.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/9.9 MB 2.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.2/9.9 MB 2.4 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.9 MB 2.0 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.9 MB 2.0 MB/s eta 0:00:03
# ...

# %%
import pandas as pd

# %%
a=[10,20,30,40,50]
pd.Series(a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
b=[5.4,3.6,6.9]
pd.Series(b)
# Out:
# 0    5.4
# 1    3.6
# 2    6.9
# dtype: float64

# %%
c=["python","course","data"]
pd.Series(c)
# Out:
# 0    python
# 1    course
# 2      data
# dtype: str

# %%
d=[4+8j,9+3j,1+4j]
pd.Series(d)
# Out:
# 0    4.0+8.0j
# 1    9.0+3.0j
# 2    1.0+4.0j
# dtype: complex128

# %%
e=[True,False]
pd.Series(e)
# Out:
# 0     True
# 1    False
# dtype: bool

# %%
details={"names":["lakshmi","prasanna","vidya"],"marks":[60,70,80]}
pd.DataFrame(details)
# Out:
#       names  marks
# 0   lakshmi     60
# 1  prasanna     70
# 2     vidya     80

# %%
details={"names":["kavya","harika","jhansi"],"mailid":["kavya@gmail.com","h@gmail.com","j@gmail.com"],"subjects":["maths","science","english"],"marks":[70,80,90],"percentages":[80,90,99]}
pd.DataFrame(details)
# Out:
#     names           mailid subjects  marks  percentages
# 0   kavya  kavya@gmail.com    maths     70           80
# 1  harika      h@gmail.com  science     80           90
# 2  jhansi      j@gmail.com  english     90           99

# %%
data=pd.read_csv("data.csv")
data
# Out:
#     Names       Mailid subjects  Marks  Percentages
# 0   kavya  k@gmail.com    maths     70           80
# 1  harika  h@gmail.com  science     80           90
# 2  jhansi  j@gmail.com  english     90           99

# %%
data.columns
# Out:
# Index(['Names', 'Mailid', 'subjects', 'Marks', 'Percentages'], dtype='str')

# %%
data.shape
# Out:
# (3, 5)

# %%
data.info
# Out:
# <bound method DataFrame.info of     Names       Mailid subjects  Marks  Percentages
# 0   kavya  k@gmail.com    maths     70           80
# 1  harika  h@gmail.com  science     80           90
# 2  jhansi  j@gmail.com  english     90           99>

# %%
data.head()
# Out:
#     Names       Mailid subjects  Marks  Percentages
# 0   kavya  k@gmail.com    maths     70           80
# 1  harika  h@gmail.com  science     80           90
# 2  jhansi  j@gmail.com  english     90           99

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data=pd.read_csv("chocolate_sales.csv")

# %%
data
# Out:
#           Order_ID             Product    Country    Channel    Salesperson  \
# 0       ORD-069833    Truffle Gift Box  Australia     Retail    Arjun Mehta
# 1       ORD-090726        85% Dark Bar  Australia     Retail    Arjun Mehta
# 2       ORD-042159        70% Dark Bar      Japan     Retail  Hannah Müller
# 3       ORD-197166   Hazelnut Milk Bar    Germany     Retail    Arjun Mehta
# 4       ORD-112162   Almond Crunch Bar  Australia     Retail      Yuki Sato
# ...            ...                 ...        ...        ...            ...
# 199995  ORD-053460        70% Dark Bar  Australia     Retail  Beatriz Souza
# 199996  ORD-010743    Truffle Gift Box      India  Wholesale    Arjun Mehta
# 199997  ORD-049690  Salted Caramel Bar      Japan     Online    Arjun Mehta
# 199998  ORD-189637        85% Dark Bar      Japan  Wholesale    Rohan Patel
# 199999  ORD-061616       Mint Dark Bar  Australia     Retail  Hannah Müller
#
# ...

# %%
data.columns
# Out:
# Index(['Order_ID', 'Product', 'Country', 'Channel', 'Salesperson',
#        'Order_Date', 'Discount_Pct', 'Price_per_Box', 'Marketing_Spend',
#        'Boxes_Shipped', 'Amount'],
#       dtype='str')

# %%
data.shape
# Out:
# (200000, 11)

# %%
data.info
# Out:
# <bound method DataFrame.info of           Order_ID             Product    Country    Channel    Salesperson  \
# 0       ORD-069833    Truffle Gift Box  Australia     Retail    Arjun Mehta
# 1       ORD-090726        85% Dark Bar  Australia     Retail    Arjun Mehta
# 2       ORD-042159        70% Dark Bar      Japan     Retail  Hannah Müller
# 3       ORD-197166   Hazelnut Milk Bar    Germany     Retail    Arjun Mehta
# 4       ORD-112162   Almond Crunch Bar  Australia     Retail      Yuki Sato
# ...            ...                 ...        ...        ...            ...
# 199995  ORD-053460        70% Dark Bar  Australia     Retail  Beatriz Souza
# 199996  ORD-010743    Truffle Gift Box      India  Wholesale    Arjun Mehta
# 199997  ORD-049690  Salted Caramel Bar      Japan     Online    Arjun Mehta
# 199998  ORD-189637        85% Dark Bar      Japan  Wholesale    Rohan Patel
# 199999  ORD-061616       Mint Dark Bar  Australia     Retail  Hannah Müller
#
# ...

# %%
from matplotlib import pyplot as plt

# %%
data["Product"].value_counts().plot(kind="pie")
plt.show()

# %%
data["Channel"].value_counts().plot(kind="bar")
plt.show()

# %%
data["Salesperson"].value_counts().plot(kind="bar")
plt.show()
